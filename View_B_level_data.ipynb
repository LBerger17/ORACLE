# %% [markdown]
# # View contents of WFIP B Level Disdrometer files

# %%
import xarray as xr
import matplotlib.pyplot as plt

# %%
file_path = "/people/gold396/ORACLE/wfip3/nant.ld.z01.b1/nant.ld.z01.b1.20250310.000000.nc"
ds = xr.open_dataset(file_path)
ds
# Out:
# <xarray.Dataset> Size: 2MB
# Dimensions:                      (time: 8640)
# Coordinates:
#   * time                         (time) datetime64[ns] 69kB 2025-03-10 ... 20...
# Data variables: (12/41)
#     rain_intensity               (time) float64 69kB ...
#     rain_accumulated             (time) float64 69kB ...
#     weather_code_synop_4680      (time) float64 69kB ...
#     weather_code_synop_4677      (time) float64 69kB ...
#     weather_code_synop_4678      (time) <U2 69kB ...
#     weather_code_nws             (time) <U1 35kB ...
#     ...                           ...
#     qc_sensor_voltage            (time) int32 35kB ...
#     qc_sensor_status             (time) int32 35kB ...
#     qc_right_sensor_temperature  (time) int32 35kB ...
#     qc_left_sensor_temperature   (time) int32 35kB ...
#     qc_kinetic_energy            (time) int32 35kB ...
#     qc_snow_intensity            (time) int32 35kB ...
# Attributes: (12/20)
#     inputs:                nant.ld.z01.b0::20250310.000000::20250311.000000
#     title:                 combine_disdrometer
#     description:           VAP to combine disdrometer data into daily files
#     Conventions:           CF-1.6
#     featureType:           timeSeries
#     institution:           Wind Data Hub
#     ...                    ...
#     serial_number:         451216
#     firmware_iop_version:  2.11.6
#     firmware_dsp_version:  2.11.1
#     deployment_time:       22:38:59_11.06.2024
#     station_name:          Barge_1
#     station_number:        PNNL

# %%
for var_name in ds.data_vars:
    plt.figure()
    ds[var_name].plot()
    plt.title(f"Plot of {var_name}")
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 3
#       1 for var_name in ds.data_vars:
#       2     plt.figure()
# ----> 3     ds[var_name].plot()
#       4     plt.title(f"Plot of {var_name}")
#       5     plt.show()
#
# File ~/.venv/lib64/python3.9/site-packages/xarray/plot/accessor.py:48, in DataArrayPlotAccessor.__call__(self, **kwargs)
#      46 @functools.wraps(dataarray_plot.plot, assigned=("__doc__", "__annotations__"))
#      47 def __call__(self, **kwargs) -> Any:
# ---> 48     return dataarray_plot.plot(self._da, **kwargs)
#
# File ~/.venv/lib64/python3.9/site-packages/xarray/plot/dataarray_plot.py:282, in plot(darray, row, col, col_wrap, ax, hue, subplot_kws, **kwargs)
#     279 plotfunc: Callable
#     281 if ndims == 0 or darray.size == 0:
# --> 282     raise TypeError("No numeric data to plot.")
#     283 if ndims in (1, 2):
#     284     if row or col:
#
# TypeError: No numeric data to plot.
